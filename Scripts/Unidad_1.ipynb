# %%
import kagglehub
import pandas as pd

path = kagglehub.dataset_download("valakhorasani/gym-members-exercise-dataset")
path_houses = kagglehub.dataset_download("aravinii/house-price-prediction-treated-dataset")

df_houses = pd.read_csv(path_houses+ "/gym_members_exercise_tracking.csv")
df = pd.read_csv(path+ "/gym_members_exercise_tracking.csv")
